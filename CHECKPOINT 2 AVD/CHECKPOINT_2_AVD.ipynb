# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/AVD/Mobiles Dataset (2025) (1).csv", encoding='latin-1')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Menggunakan df Untuk Menampilkan Seluruh Data

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#      Launched Year Launched Price in USA (USD) RAM (GB) Front Camera (MP)  \
# ...

# %% [markdown]
# Menggunakan df.head(5) untuk menampilkan 5 Data Teratas

# %%
df.head(5)
# Out:
#   Company Name            Model Name Mobile Weight   Processor  Launched Year  \
# 0        Apple       iPhone 16 128GB          174g  A17 Bionic           2024
# 1        Apple       iPhone 16 256GB          174g  A17 Bionic           2024
# 2        Apple       iPhone 16 512GB          174g  A17 Bionic           2024
# 3        Apple  iPhone 16 Plus 128GB          203g  A17 Bionic           2024
# 4        Apple  iPhone 16 Plus 256GB          203g  A17 Bionic           2024
#
#   Launched Price in USA (USD) RAM (GB) Front Camera (MP) Back Camera (MP)  \
# 0                         799        6                12               48
# 1                         849        6                12               48
# 2                         899        6                12               48
# 3                         899        6                12               48
# 4                         949        6                12               48
#
#   Screen Size (Inches)  Battery Capacity (mAh)
# ...

# %% [markdown]
# Menggunakan df.info Untuk Menampilkan Informasi Mengenai Dataset

# %%
df.info
# Out:
# <bound method DataFrame.info of     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
# ...

# %% [markdown]
# Menampilkan Jumlah Baris dan Kolom

# %%
print(f"Baris: {df.shape[0]}, Kolom: {df.shape[1]}")
# Out:
# Baris: 915, Kolom: 11

# %% [markdown]
# Mengecek Tipe Data

# %%
df.dtypes
# Out:
# Company Name                   object
# Model Name                     object
# Mobile Weight                  object
# Processor                      object
# Launched Year                   int64
# Launched Price in USA (USD)    object
# RAM (GB)                       object
# Front Camera (MP)              object
# Back Camera (MP)               object
# Screen Size (Inches)           object
# Battery Capacity (mAh)          int64
# dtype: object

# %% [markdown]
# ## Statistik Deskriptif

# %%
df.describe()
# Out:
#        Launched Year  Battery Capacity (mAh)
# count     915.000000              915.000000
# mean     2022.205464             5030.280874
# std         1.869182             1365.571834
# min      2014.000000             2000.000000
# 25%      2021.000000             4400.000000
# 50%      2023.000000             5000.000000
# 75%      2024.000000             5100.000000
# max      2025.000000            11200.000000

# %%
df.value_counts()
# Out:
# Company Name  Model Name            Mobile Weight  Processor                       Launched Year  Launched Price in USA (USD)  RAM (GB)  Front Camera (MP)  Back Camera (MP)                              Screen Size (Inches)  Battery Capacity (mAh)
# Apple         iPad 10.2-inch 128GB  490g           A13 Bionic                      2020           429                          3         12                 8                                             10.2                  8612                      1
# Realme        13 Pro+ 5G 256GB      195g           Qualcomm Snapdragon 7+ Gen 2    2024           360                          12        32                 50 + 8 + 50                                   6.78                  5500                      1
# ...

# %% [markdown]
# ### Menghitung korelasi antar kolom numerik dengan df.corr

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#                         Launched Year  Battery Capacity (mAh)
# Launched Year                1.000000                0.351488
# Battery Capacity (mAh)       0.351488                1.000000

# %% [markdown]
# ## df.mean

# %%
("\nMenghitung rata-rata kolom numerik dengan df.mean():")
print(df.mean(numeric_only=True))
# Out:
# Launched Year             2022.205464
# Battery Capacity (mAh)    5030.280874
# dtype: float64

# %% [markdown]
# ## df.std

# %%
print("\nMenghitung standar deviasi kolom numerik dengan df.std():")
print(df.std(numeric_only=True))
# Out:
# Menghitung standar deviasi kolom numerik dengan df.std():
# Launched Year                1.869182
# Battery Capacity (mAh)    1365.571834
# dtype: float64

# %% [markdown]
# ## df.median

# %%
print("\nMenghitung median kolom numerik dengan df.median():")
print(df.median(numeric_only=True))
# Out:
# Menghitung median kolom numerik dengan df.median():
# Launched Year             2023.0
# Battery Capacity (mAh)    5000.0
# dtype: float64

# %% [markdown]
# # **Pengecekan Terhadap Missing Values, Duplikat, Outliers, dan Inconsistent Values.**

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Memeriksa Apakah Terdapat Missing Value Dalam Dataset Ini, dan Hasilnya Tidak Ditemmukan Adanya Missing Value

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Company Name                 0.0
# Model Name                   0.0
# Mobile Weight                0.0
# RAM                          0.0
# Front Camera                 0.0
# Back Camera                  0.0
# Processor                    0.0
# Battery Capacity             0.0
# Screen Size                  0.0
# Launched Price (Pakistan)    0.0
# Launched Price (India)       0.0
# Launched Price (China)       0.0
# Launched Price (USA)         0.0
# Launched Price (Dubai)       0.0
# Launched Year                0.0
# dtype: float64

# %% [markdown]
# ## Duplicate Data

# %% [markdown]
# Memeriksa dan Menghapus Data Yang Memiliki Duplicate

# %%
df[df.duplicated()]
# Out:
#     Company Name        Model Name Mobile Weight   RAM Front Camera  \
# 347         Oppo          A3 128GB          186g   4GB          5MP
# 437         Oppo        K11x 128GB          195g   8GB         16MP
# 438         Oppo        K11x 256GB          195g  12GB         16MP
# 441         Oppo        K10x 128GB          195g   6GB         16MP
# 442         Oppo        K10x 256GB          195g   8GB         16MP
# 443         Oppo      K10 5G 128GB          205g   8GB         16MP
# 445         Oppo         K9x 128GB          194g   6GB         16MP
# 446         Oppo         K9x 256GB          194g   8GB         16MP
# 447         Oppo   K9 Pro 5G 128GB          180g   8GB         16MP
# 448         Oppo   K9 Pro 5G 256GB          180g  12GB         16MP
# 449         Oppo       K9 5G 128GB          172g   8GB         32MP
# 450         Oppo       K9 5G 256GB          172g   8GB         32MP
# 451         Oppo         K7x 128GB          194g   6GB         16MP
# ...

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Company Name, Model Name, Mobile Weight, RAM, Front Camera, Back Camera, Processor, Battery Capacity, Screen Size, Launched Price (Pakistan), Launched Price (India), Launched Price (China), Launched Price (USA), Launched Price (Dubai), Launched Year]
# Index: []

# %% [markdown]
# ## Outliers

# %% [markdown]
# Mengecek Apakah Dataset Ini Memiliki Outliers di Atas 10%, Jika Iya Maka Data Perlu Ditangani Denfan Imputasi.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# Launched Year             0.765027

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# ## Inconsistent Values

# %% [markdown]
# Menghapus Tanda Koma Yang Tidak Konsisten Pada Battery Capacity

# %%
df["Battery Capacity"] = df["Battery Capacity"].str.replace(",", "", regex=True)
# Out:
# <ipython-input-53-4ec4971437cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Battery Capacity"] = df["Battery Capacity"].str.replace(",", "", regex=True)

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# Membersihkan Kolom Company Name Agar Konsisten Dalam Format Huruf Kapital

# %%
df["Company Name"] = df["Company Name"].str.strip().str.title()
print(df["Company Name"].unique())
# Out:
# ['Apple' 'Samsung' 'Oneplus' 'Vivo' 'Iqoo' 'Oppo' 'Realme' 'Xiaomi'
#  'Lenovo' 'Motorola' 'Huawei' 'Nokia' 'Sony' 'Google' 'Tecno' 'Infinix'
#  'Honor' 'Poco']
# <ipython-input-73-a8f7e38f77f6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Company Name"] = df["Company Name"].str.strip().str.title()

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#      Launched Year Launched Price in USA (USD) RAM (GB) Front Camera (MP)  \
# ...

# %% [markdown]
# # **Penanganan Terhadap Missing Values, Duplikat, Outliers, dan Inconsistent Values.**

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Tidak terdapat missing value pada dataset ini.

# %% [markdown]
# ## Duplicate Data

# %% [markdown]
# menghapus data duplikat yang ada pada dataset ini

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Company Name, Model Name, Mobile Weight, RAM, Front Camera, Back Camera, Processor, Battery Capacity, Screen Size, Launched Price (Pakistan), Launched Price (India), Launched Price (China), Launched Price (USA), Launched Price (Dubai), Launched Year]
# Index: []

# %% [markdown]
# ## Outliers

# %% [markdown]
# outliers tidak melebihi 10%, maka bisa di abaikan

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# Launched Year             0.765027

# %% [markdown]
# ## Inconsistent Values

# %% [markdown]
# menghapus tanda koma yang tidak konsisten pada kolom Battery Capacity

# %%
df["Battery Capacity"] = df["Battery Capacity"].str.replace(",", "", regex=True)
# Out:
# <ipython-input-30-4ec4971437cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Battery Capacity"] = df["Battery Capacity"].str.replace(",", "", regex=True)

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# Membersihkan Kolom Company Name Agar Konsisten Dalam Format Huruf Kapital

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#      Launched Year Launched Price in USA (USD) RAM (GB) Front Camera (MP)  \
# ...

# %% [markdown]
# # Construct Data

# %% [markdown]
# Membuat Kolom Baru Setelah Menghapus Kata 'GB' Yang Terdapat Pada Isi Dataset dan Memindahkannya Pada Judul Kolom Untuk Mempermudah Proses Analisis dan Visualisasi.

# %%
df["RAM (GB)"] = df["RAM"].str.replace("GB", "").str.strip()
df[["RAM", "RAM (GB)"]].head()
# Out:
# <ipython-input-60-12643b888ed5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RAM (GB)"] = df["RAM"].str.replace("GB", "").str.strip()
#    RAM RAM (GB)
# 0  6GB        6
# 1  6GB        6
# 2  6GB        6
# 3  6GB        6
# 4  6GB        6

# %% [markdown]
# Membuat Kolom Baru Setelah Menghapus Kata 'MP' Yang Terdapat Pada Isi Dataset dan Memindahkannya Pada Judul Kolom Untuk Mempermudah Proses Analisis dan Visualisasi.

# %%
df["Front Camera (MP)"] = df["Front Camera"].str.replace("MP", "").str.strip()
df["Back Camera (MP)"] = df["Back Camera"].str.replace("MP", "").str.strip()


df.drop(columns=["Front Camera", "Back Camera"], inplace=True, errors="ignore")
df[["Front Camera (MP)", "Back Camera (MP)"]].head()
# Out:
# <ipython-input-63-d5871a64f915>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Front Camera (MP)"] = df["Front Camera"].str.replace("MP", "").str.strip()
# <ipython-input-63-d5871a64f915>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Back Camera (MP)"] = df["Back Camera"].str.replace("MP", "").str.strip()
# <ipython-input-63-d5871a64f915>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#     Battery Capacity  Screen Size  Launched Year Launched Price in USA (USD)  \
# ...

# %% [markdown]
# Membuat Kolom Baru Setelah Menghapus Kata 'inches' Yang Terdapat Pada Isi Dataset dan Memindahkannya Pada Judul Kolom Untuk Mempermudah Proses Analisis dan Visualisasi.

# %%
df["Screen Size (Inches)"] = df["Screen Size"].str.replace("inches", "").str.strip()
df.drop(columns=["Screen Size"], inplace=True, errors="ignore")


df[["Screen Size (Inches)"]].head()
# Out:
# <ipython-input-69-7207f82bbf3c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Screen Size (Inches)"] = df["Screen Size"].str.replace("inches", "").str.strip()
# <ipython-input-69-7207f82bbf3c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Screen Size"], inplace=True, errors="ignore")
#   Screen Size (Inches)
# 0                  6.1
# 1                  6.1
# 2                  6.1
# 3                  6.7
# 4                  6.7

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#     Battery Capacity  Launched Year Launched Price in USA (USD) RAM (GB)  \
# ...

# %% [markdown]
# Membuat Kolom Baru Setelah Menghapus Kata 'mAh' Yang Terdapat Pada Isi Dataset dan Memindahkannya Pada Judul Kolom Untuk Mempermudah Proses Analisis dan Visualisasi.

# %%
df["Battery Capacity (mAh)"] = df["Battery Capacity"].str.replace(",", "").str.replace("mAh", "").str.strip().astype(int)
df.drop(columns=["Battery Capacity"], inplace=True, errors="ignore")

df[["Battery Capacity (mAh)"]].head()
# Out:
# <ipython-input-71-88545e6a292a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Battery Capacity (mAh)"] = df["Battery Capacity"].str.replace(",", "").str.replace("mAh", "").str.strip().astype(int)
# <ipython-input-71-88545e6a292a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Battery Capacity"], inplace=True, errors="ignore")
#    Battery Capacity (mAh)
# 0                    3600
# 1                    3600
# 2                    3600
# 3                    4200
# 4                    4200

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight            Processor  \
# 0          Apple       iPhone 16 128GB          174g           A17 Bionic
# 1          Apple       iPhone 16 256GB          174g           A17 Bionic
# 2          Apple       iPhone 16 512GB          174g           A17 Bionic
# 3          Apple  iPhone 16 Plus 128GB          203g           A17 Bionic
# 4          Apple  iPhone 16 Plus 256GB          203g           A17 Bionic
# ..           ...                   ...           ...                  ...
# 925         Poco          Pad 5G 128GB          571g  Snapdragon 7s Gen 2
# 926         Poco          Pad 5G 256GB          571g  Snapdragon 7s Gen 2
# 927      Samsung  Galaxy Z Fold6 256GB          239g   Snapdragon 8 Gen 3
# 928      Samsung  Galaxy Z Fold6 512GB          239g   Snapdragon 8 Gen 3
# 929      Samsung    Galaxy Z Fold6 1TB          239g   Snapdragon 8 Gen 3
#
#      Launched Year Launched Price in USA (USD) RAM (GB) Front Camera (MP)  \
# ...

# %% [markdown]
# # Data Reduction

# %% [markdown]
# Menghapus Launched Prize Negara Lainnya dan Hanya Menggunakan Launched Prize USA

# %%
columns_to_drop = [
    "Launched Price (Pakistan)", "Launched Price (India)",
    "Launched Price (China)", "Launched Price (Dubai)"
]

df.drop(columns=columns_to_drop, inplace=True, errors="ignore")
# Out:
# <ipython-input-56-4db3027b2948>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors="ignore")

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# Menghapus USD Yang Terletak di Samping Harga dan Memindahkannya ke Judul Kolom Untuk Mempermudah Analisis dan Visualisasi.

# %%
df["Launched Price in USA (USD)"] = df["Launched Price (USA)"].str.replace("USD", "").str.strip()
df.drop(columns=["Launched Price (USA)"], inplace=True)

df[["Launched Price in USA (USD)"]].head()
# Out:
# <ipython-input-58-97a5a220d760>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Launched Price in USA (USD)"] = df["Launched Price (USA)"].str.replace("USD", "").str.strip()
# <ipython-input-58-97a5a220d760>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Launched Price (USA)"], inplace=True)
#   Launched Price in USA (USD)
# 0                         799
# 1                         849
# 2                         899
# 3                         899
# 4                         949

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# Menghapus Kolom RAM Yang Lama Karena Sudah Tidak Diperlukan

# %%
df.drop(columns=["RAM"], inplace=True)
df.head()
# Out:
# <ipython-input-62-e2596ee9ad07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["RAM"], inplace=True)
#   Company Name            Model Name Mobile Weight Front Camera Back Camera  \
# 0        Apple       iPhone 16 128GB          174g         12MP        48MP
# 1        Apple       iPhone 16 256GB          174g         12MP        48MP
# 2        Apple       iPhone 16 512GB          174g         12MP        48MP
# 3        Apple  iPhone 16 Plus 128GB          203g         12MP        48MP
# 4        Apple  iPhone 16 Plus 256GB          203g         12MP        48MP
#
#     Processor Battery Capacity Screen Size  Launched Year  \
# 0  A17 Bionic          3600mAh  6.1 inches           2024
# 1  A17 Bionic          3600mAh  6.1 inches           2024
# ...
